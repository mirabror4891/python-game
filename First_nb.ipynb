# %% [markdown]
# <a href="https://colab.research.google.com/github/mirabror4891/python-game/blob/main/First_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# #Heading
# - Open [mohirdev.uz](https://)
# - Themes

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import tensorflow as tf
import keras

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
torch.__version__
# Out:
# '2.3.1+cu121'

# %%
torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2eaca526b1e6> in <cell line: 1>()
# ----> 1 torch.cuda.is_available()
#
# NameError: name 'torch' is not defined

# %%
torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2eaca526b1e6> in <cell line: 1>()
# ----> 1 torch.cuda.is_available()
#
# NameError: name 'torch' is not defined

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
! Ls
# Out:
# /bin/bash: line 1: Ls: command not found

# %%
! is
# Out:
# /bin/bash: line 1: is: command not found

# %%
Is
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7197e1381a10> in <cell line: 1>()
# ----> 1 Is
#
# NameError: name 'Is' is not defined

# %%
! ls
# Out:
# sample_data

# %%
! ls
# Out:
# Data  sample_data

# %%
import pandas as pd
files = pd.read.excel('./Data/Training.xlsx')
files.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d9e25cbc627b> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 files=pd.read.excel('./Data/Training.xlsx')
#       3 files.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
import pandas as pd
files = pd.read_excel('./Data/Training.xlsx')
files.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-279fa8287c14> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 files = pd.read.excel('./Data/Training.xlsx')
#       3 files.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
import pandas as pd
files = pd.read_excel('./Data/Training.xlsx')
files.head()
# Out:
#         Familiya       Ism          Mansab  Shtat      Oylik    Daromad  \
# 0  Gulomqodirova  Shahnoza      Oliy Toifa   1.25  2700000.0  3375000.0
# 1        Aliyeva   Nazokat  Birinchi Toifa   1.00  2350000.0  2350000.0
# 2       O'ktamov   Jamshid  Ikkinchi Toifa   0.50  2000000.0  1000000.0
# 3        Nodirov     Akbar  Ikkinchi Toifa   0.25  2000000.0   500000.0
# 4         Azimov   Alisher      Oliy Toifa   1.00  2700000.0  2700000.0
#
#    Qo'lga tegadigan summa  Jinsi
# 0               2970000.0   Ayol
# 1               2068000.0   Ayol
# 2                880000.0  Erkak
# 3                440000.0  Erkak
# 4               2376000.0  Erkak
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Shtat'].plot(kind='hist', bins=20, title='Shtat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...
